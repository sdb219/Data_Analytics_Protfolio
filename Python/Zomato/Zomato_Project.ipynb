# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\DELL\Downloads\zomato.csv", encoding='latin1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info() #checking_the_basic_data_structures
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [raw]
# #Initial_Exploration_of_Data

# %%
df.isnull().sum() #checking_null_values_for_each_column
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.describe() #for some basic statistics
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.columns  #for_column_names
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
#Insights_for_above
#Rename columns (they usually have weird names in this dataset)

#Drop irrelevant columns (some columns are just IDs or not useful)

#Deal with missing/duplicate values

# %%
df=df.dropna(subset=['Cuisines']) #droped_the_null_names

# %%
df.isnull().sum() #checking_null_values_for_each_column
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#Column_names_cleanup
df.columns = df.columns.str.strip().str.lower().str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['restaurant_id', 'restaurant_name', 'country_code', 'city', 'address',
#        'locality', 'locality_verbose', 'longitude', 'latitude', 'cuisines',
#        'average_cost_for_two', 'currency', 'has_table_booking',
#        'has_online_delivery', 'is_delivering_now', 'switch_to_order_menu',
#        'price_range', 'aggregate_rating', 'rating_color', 'rating_text',
#        'votes'],
#       dtype='object')

# %%
#EXPLORATORY_DATA_ANALYSIS

# %%
#Finding the top 10 cities with most restaurants

import matplotlib.pyplot as plt
import seaborn as sns

top_cities=df['city'].value_counts().head(10)
plt.figure(figsize=(12,6))
sns.barplot(x=top_cities.values,y=top_cities.index, palette='viridis', hue=top_cities.index, dodge=False, legend=False)
plt.title('Top 10 cities with Most Restaurants', fontsize=16)
plt.xlabel('Number of Restaurants')
plt.ylabel('City')
plt.tight_layout()
plt.show()

# %%
#Rating Distribution

plt.figure(figsize=(10,5))
sns.countplot(x='aggregate_rating', data=df, palette='coolwarm',hue='aggregate_rating',dodge=False,legend=False)
plt.title('Distribution of Aggregate Ratings', fontsize=16)
plt.xlabel('Aggregate Rating')
plt.ylabel('Number of Restaurants')
plt.tight_layout()
plt.show()

# %%
#Average Cost for Two by City

# Find the dominant price range for each city
dominant_price_range = df.groupby('city')['price_range'].agg(lambda x: x.mode()[0])

# Average cost per city
avg_cost_city = df.groupby('city')['average_cost_for_two'].mean()

# Combine into a single DataFrame
city_cost_df = pd.DataFrame({
    'avg_cost': avg_cost_city,
    'dominant_price_range': dominant_price_range
}).reset_index()

# Sort descending by average cost and pick top 10
top_cities_cost = city_cost_df.sort_values(by='avg_cost', ascending=False).head(10)

# Plot with hue and legend
plt.figure(figsize=(12, 6))
sns.barplot(x='avg_cost', y='city', data=top_cities_cost,
            hue='dominant_price_range', palette='viridis')

plt.title('Top 10 Cities by Average Cost for Two with Dominant Price Range', fontsize=16)
plt.xlabel('Average Cost for Two')
plt.ylabel('City')
plt.legend(title='Dominant Price Range', loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Step 1: Create a DataFrame from country_counts
country_df = country_counts.reset_index()
country_df.columns = ['country', 'restaurant_count']

# Step 2: Add a hue column - Restaurant volume category
def volume_category(count):
    if count > 1000:
        return 'High'
    elif count > 100:
        return 'Medium'
    else:
        return 'Low'

country_df['volume_category'] = country_df['restaurant_count'].apply(volume_category)

# Step 3: Plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=country_df,
    x='restaurant_count',
    y='country',
    hue='volume_category',
    palette='crest'
)

plt.title('Top Countries by Number of Restaurants Listed', fontsize=16)
plt.xlabel('Number of Restaurants')
plt.ylabel('Country')
plt.legend(title='Restaurant Volume')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(
    data=price_group,
    x='restaurant_count',
    y='label',
    hue='label',
    palette='flare',
    dodge=False,
    legend= False  # Keep bars stacked together
)

plt.title('Restaurant Count by Price Category', fontsize=16)
plt.xlabel('Number of Restaurants')
plt.ylabel('Price Category')
plt.tight_layout()
plt.show()

# %%
# Filter for India (country_code = 1)
india_df = df[df['country_code'] == 1]
# Count restaurants with table booking by city
table_booking_cities = india_df[india_df['has_table_booking'] == 'Yes']['city'].value_counts().head(10)

print(table_booking_cities)

top_cities = table_booking_cities.index.tolist()

# Filter for only these cities
india_top_cities_df = india_df[india_df['city'].isin(top_cities)]

# Aggregate counts of 'Yes' for table booking and online delivery per city
booking_delivery_counts = india_top_cities_df.groupby('city').agg({
    'has_table_booking': lambda x: (x == 'Yes').sum(),
    'has_online_delivery': lambda x: (x == 'Yes').sum()
}).reset_index()

# Melt the dataframe for seaborn
booking_delivery_melted = booking_delivery_counts.melt(id_vars='city', 
                                                      value_vars=['has_table_booking', 'has_online_delivery'], 
                                                      var_name='Service', value_name='Count')

# Rename for clarity
booking_delivery_melted['Service'] = booking_delivery_melted['Service'].map({
    'has_table_booking': 'Table Booking',
    'has_online_delivery': 'Online Delivery'
})

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(data=booking_delivery_melted, x='Count', y='city', hue='Service', palette='viridis',dodge=False,legend=False)
plt.title('Table Booking vs Online Delivery in Top Indian Cities', fontsize=16)
plt.xlabel('Number of Restaurants')
plt.ylabel('City')
plt.tight_layout()
plt.show()
# Out:
# city
# New Delhi    715
# Gurgaon      204
# Noida        112
# Faridabad     15
# Chennai       13
# Pune          13
# Hyderabad     10
# Kolkata        9
# Mumbai         9
# Bangalore      6
# Name: count, dtype: int64
